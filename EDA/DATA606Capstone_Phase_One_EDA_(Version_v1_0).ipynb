# %% [markdown]
# <a href="https://colab.research.google.com/github/IradukundaHN/Hugues_DATA606/blob/main/EDA/DATA606Capstone_Phase_One_EDA_(Version_v1_0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA 606 Capstone
# ## Exploratory Data Analysis Phase 1

# %% [markdown]
# This Notebook contains the first EDA Phase of the project.

# %% [markdown]
# ## Import librairies

# %%
# Packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading data

# %%
# Data sources
travel_data =  pd.read_csv('/content/Travel Restrictions - travel.csv')
global_data = pd.read_csv('/content/WHO-COVID-19-global-table-data.csv')
vaccination_data = pd.read_csv('/content/vaccination-data.csv')

# %% [markdown]
# ## Data Exploratory Analysis

# %% [markdown]
# ## Travel data

# %%
print(f'Rows: {travel_data.shape[0]:,}')
print(f'Columns: {travel_data.shape[1]:,}')
# Out:
# Rows: 290
# Columns: 12

# %%
# Display 5 first observations contents
travel_data.head()
# Out:
#        adm0_name      iso3  ...  optional4  Unnamed: 11
# 0          Abyei  SDN, SSD  ...        NaN          NaN
# 1    Afghanistan       AFG  ...        NaN          NaN
# 2       Akrotiri       xUK  ...        NaN          NaN
# 3     Aksai Chin  AKS, CHN  ...        NaN          NaN
# 4  Åland Islands       ALA  ...        NaN          NaN
#
# [5 rows x 12 columns]

# %%
# Data types
travel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   adm0_name    290 non-null    object
#  1   iso3         290 non-null    object
#  2   X            290 non-null    float64
#  3   Y            289 non-null    float64
#  4   published    236 non-null    object
#  5   sources      236 non-null    object
#  6   info         236 non-null    object
#  7   optional1    236 non-null    float64
#  8   optional2    235 non-null    object
#  9   optional3    234 non-null    object
#  10  optional4    120 non-null    object
#  11  Unnamed: 11  1 non-null      object
# dtypes: float64(3), object(9)
# memory usage: 27.3+ KB

# %%
travel_data.describe(include='all')
# Out:
#        adm0_name  ...                                        Unnamed: 11
# count        290  ...                                                  1
# unique       290  ...                                                  1
# top        Abyei  ...  All persons 18 years and over arriving into Gh...
# freq           1  ...                                                  1
# mean         NaN  ...                                                NaN
# std          NaN  ...                                                NaN
# min          NaN  ...                                                NaN
# 25%          NaN  ...                                                NaN
# 50%          NaN  ...                                                NaN
# 75%          NaN  ...                                                NaN
# max          NaN  ...                                                NaN
#
# [11 rows x 12 columns]

# %%
# Missing values
travel_data.isnull().sum()
# Out:
# adm0_name        0
# iso3             0
# X                0
# Y                1
# published       54
# sources         54
# info            54
# optional1       54
# optional2       55
# optional3       56
# optional4      170
# Unnamed: 11    289
# dtype: int64

# %% [markdown]
# ## Global cases data

# %%
print(f'Rows: {global_data.shape[0]:,}')
print(f'Columns: {global_data.shape[1]:,}')
# Out:
# Rows: 238
# Columns: 12

# %%
# Display 5 first observations contents
global_data.head()
# Out:
#                                      Name  ...  Deaths - newly reported in last 24 hours
# Global                                NaN  ...                                       NaN
# United States of America         Americas  ...                                       NaN
# India                     South-East Asia  ...                                       NaN
# Brazil                           Americas  ...                                       NaN
# France                             Europe  ...                                       NaN
#
# [5 rows x 12 columns]

# %%
# Data types
global_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 238 entries, Global to Tuvalu
# Data columns (total 12 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Name                                                          237 non-null    object
#  1   WHO Region                                                    238 non-null    int64
#  2   Cases - cumulative total                                      237 non-null    float64
#  3   Cases - cumulative total per 100000 population                238 non-null    int64
#  4   Cases - newly reported in last 7 days                         237 non-null    float64
#  5   Cases - newly reported in last 7 days per 100000 population   238 non-null    int64
#  6   Cases - newly reported in last 24 hours                       238 non-null    int64
# ...

# %%
global_data.describe(include='all')
# Out:
#           Name  ...  Deaths - newly reported in last 24 hours
# count      237  ...                                       0.0
# unique       7  ...                                       NaN
# top     Europe  ...                                       NaN
# freq        62  ...                                       NaN
# mean       NaN  ...                                       NaN
# std        NaN  ...                                       NaN
# min        NaN  ...                                       NaN
# 25%        NaN  ...                                       NaN
# 50%        NaN  ...                                       NaN
# 75%        NaN  ...                                       NaN
# max        NaN  ...                                       NaN
#
# [11 rows x 12 columns]

# %%
# Missing values
global_data.isnull().sum()
# Out:
# Name                                                              1
# WHO Region                                                        0
# Cases - cumulative total                                          1
# Cases - cumulative total per 100000 population                    0
# Cases - newly reported in last 7 days                             1
# Cases - newly reported in last 7 days per 100000 population       0
# Cases - newly reported in last 24 hours                           0
# Deaths - cumulative total                                         1
# Deaths - cumulative total per 100000 population                   0
# Deaths - newly reported in last 7 days                            1
# Deaths - newly reported in last 7 days per 100000 population      0
# Deaths - newly reported in last 24 hours                        238
# dtype: int64

# %% [markdown]
# ## Vaccination data

# %%
print(f'Rows: {vaccination_data.shape[0]:,}')
print(f'Columns: {vaccination_data.shape[1]:,}')
# Out:
# Rows: 228
# Columns: 14

# %%
# Display 5 first observations contents
vaccination_data.head()
# Out:
#           COUNTRY ISO3  ... FIRST_VACCINE_DATE NUMBER_VACCINES_TYPES_USED
# 0     Afghanistan  AFG  ...         2021-02-22                        4.0
# 1         Albania  ALB  ...         2021-01-13                        5.0
# 2         Algeria  DZA  ...         2021-01-30                        4.0
# 3  American Samoa  ASM  ...         2020-12-21                        3.0
# 4         Andorra  AND  ...         2021-01-20                        3.0
#
# [5 rows x 14 columns]

# %%
# Data types
vaccination_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228 entries, 0 to 227
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COUNTRY                               228 non-null    object
#  1   ISO3                                  228 non-null    object
#  2   WHO_REGION                            228 non-null    object
#  3   DATA_SOURCE                           228 non-null    object
#  4   DATE_UPDATED                          228 non-null    object
#  5   TOTAL_VACCINATIONS                    228 non-null    int64
#  6   PERSONS_VACCINATED_1PLUS_DOSE         225 non-null    float64
#  7   TOTAL_VACCINATIONS_PER100             228 non-null    float64
#  8   PERSONS_VACCINATED_1PLUS_DOSE_PER100  225 non-null    float64
#  9   PERSONS_FULLY_VACCINATED              225 non-null    float64
#  10  PERSONS_FULLY_VACCINATED_PER100       225 non-null    float64
# ...

# %%
vaccination_data.describe(include='all')
# Out:
#             COUNTRY ISO3  ... FIRST_VACCINE_DATE NUMBER_VACCINES_TYPES_USED
# count           228  228  ...                208                 225.000000
# unique          228  228  ...                102                        NaN
# top     Afghanistan  AFG  ...         2020-12-23                        NaN
# freq              1    1  ...                 19                        NaN
# mean            NaN  NaN  ...                NaN                   3.928889
# std             NaN  NaN  ...                NaN                   1.928247
# min             NaN  NaN  ...                NaN                   1.000000
# 25%             NaN  NaN  ...                NaN                   2.000000
# 50%             NaN  NaN  ...                NaN                   4.000000
# 75%             NaN  NaN  ...                NaN                   5.000000
# max             NaN  NaN  ...                NaN                  11.000000
#
# [11 rows x 14 columns]

# %%
# Missing values
vaccination_data.isnull().sum()
# Out:
# COUNTRY                                  0
# ISO3                                     0
# WHO_REGION                               0
# DATA_SOURCE                              0
# DATE_UPDATED                             0
# TOTAL_VACCINATIONS                       0
# PERSONS_VACCINATED_1PLUS_DOSE            3
# TOTAL_VACCINATIONS_PER100                0
# PERSONS_VACCINATED_1PLUS_DOSE_PER100     3
# PERSONS_FULLY_VACCINATED                 3
# PERSONS_FULLY_VACCINATED_PER100          3
# VACCINES_USED                            3
# FIRST_VACCINE_DATE                      20
# NUMBER_VACCINES_TYPES_USED               3
# dtype: int64

# %% [markdown]
# ## Heatmap for correlation

# %%
sns.heatmap(global_data.corr())
plt.show()

# %%
sns.heatmap(vaccination_data.corr())
plt.show()

# %% [markdown]
# ## Histogram distribution

# %%
travel_data.optional3.value_counts()[:3].plot(kind='barh')
plt.title('Distribution of the top 3 travel restrictions', loc='left')
plt.show()

# %% [markdown]
# ## Distribution plots

# %%
sns.distplot(global_data['Cases - cumulative total'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(vaccination_data['TOTAL_VACCINATIONS'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
